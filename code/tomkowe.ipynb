# %%
import time

import numpy as np
import pandas as pd
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis,
    QuadraticDiscriminantAnalysis,
)
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.feature_selection import (
    RFE,
    SelectFromModel,
    SelectKBest,
    SequentialFeatureSelector,
    f_classif,
    mutual_info_classif,
)
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from utils import (
    experiment,
    get_data,
    get_param_combinations,
    get_params_json,
    save_results,
)

from xgboost import XGBClassifier

# %%
X, y = get_data()

# %%
def run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds=[42]):
    for fs in feature_selectors:
        for clf in classifiers:
            for k in ks:
                # Generate parameter combinations
                fs_cls, fs_params, k_param_name, requires_estimator = fs
                clf_cls, clf_params = clf

                fs_param_combinations = get_param_combinations(fs_params)
                clf_param_combinations = get_param_combinations(clf_params)

                for fs_params in fs_param_combinations:
                    for clf_params in clf_param_combinations:
                        result = experiment(
                            X,
                            y,
                            fs_cls,
                            fs_params,
                            clf_cls,
                            clf_params,
                            k,
                            k_param_name,
                            requires_estimator,
                            train_test_seeds,
                        )

                        print(result)
                        print(f"Elapsed time: {result[-1]:.2f}s\n")
                        results.append(result)
                        save_results(results, filename)

# %%
results = []

filename = "tomkowe_tree"

feature_selectors = [
    (SelectFromModel, {"threshold": [-np.inf]}, "max_features", True)
]

classifiers = [
    (
        XGBClassifier,
        {
            "booster": ["gbtree"],
            "device": ["gpu"],
            "learning_rate": [0.001, 0.01, 0.1, 0.3, 0.5],
            "n_estimators": [10, 75, 150],
            "min_child_weight": [0.5, 1, 3, 5],
            "max_depth": [2, 6, 10],
            "tree_method": ["auto", "hist", "approx"]
        },
    )
]

ks = np.arange(1, 10, 1)
train_test_seeds = list(range(42, 45))

run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds)
# Out:
# c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\core.py:160: UserWarning: [21:31:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 0.5, 'max_depth': 2, 'tree_method': 'auto'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.33304057121276853)
# Elapsed time: 0.33s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 0.5, 'max_depth': 2, 'tree_method': 'hist'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.2792048454284668)
# Elapsed time: 0.28s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 0.5, 'max_depth': 2, 'tree_method': 'approx'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.4972671031951904)
# Elapsed time: 0.50s
#
# 42 0.563
# 43 0.563
# 44 0.553
# 45 0.542
# 46 0.548
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 0.5, 'max_depth': 6, 'tree_method': 'auto'}", 1, 0.5538000000000001, 0.008280096617793739, 0.619, 0.4239181041717529)
# Elapsed time: 0.42s
#
# 42 0.563
# 43 0.563
# 44 0.553
# 45 0.542
# 46 0.548
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 0.5, 'max_depth': 6, 'tree_method': 'hist'}", 1, 0.5538000000000001, 0.008280096617793739, 0.619, 0.4294215202331543)
# Elapsed time: 0.43s
#
# 42 0.563
# 43 0.563
# 44 0.553
# 45 0.542
# 46 0.548
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 0.5, 'max_depth': 6, 'tree_method': 'approx'}", 1, 0.5538000000000001, 0.008280096617793739, 0.619, 0.7174274921417236)
# Elapsed time: 0.72s
#
# 42 0.527
# 43 0.545
# 44 0.545
# 45 0.508
# 46 0.55
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 0.5, 'max_depth': 10, 'tree_method': 'auto'}", 1, 0.5349999999999999, 0.01560769041210135, 0.595, 0.9664030075073242)
# Elapsed time: 0.97s
#
# 42 0.527
# 43 0.545
# 44 0.545
# 45 0.508
# 46 0.55
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 0.5, 'max_depth': 10, 'tree_method': 'hist'}", 1, 0.5349999999999999, 0.01560769041210135, 0.595, 0.9969403266906738)
# Elapsed time: 1.00s
#
# 42 0.529
# 43 0.545
# 44 0.545
# 45 0.508
# 46 0.55
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 0.5, 'max_depth': 10, 'tree_method': 'approx'}", 1, 0.5354000000000001, 0.015422062118925614, 0.593, 1.928432035446167)
# Elapsed time: 1.93s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 1, 'max_depth': 2, 'tree_method': 'auto'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.24983596801757812)
# Elapsed time: 0.25s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 1, 'max_depth': 2, 'tree_method': 'hist'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.28123788833618163)
# Elapsed time: 0.28s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 1, 'max_depth': 2, 'tree_method': 'approx'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.523187255859375)
# Elapsed time: 0.52s
#
# 42 0.563
# 43 0.563
# 44 0.553
# 45 0.542
# 46 0.548
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 1, 'max_depth': 6, 'tree_method': 'auto'}", 1, 0.5538000000000001, 0.008280096617793739, 0.619, 0.4222412109375)
# Elapsed time: 0.42s
#
# 42 0.563
# 43 0.563
# 44 0.553
# 45 0.542
# 46 0.548
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 1, 'max_depth': 6, 'tree_method': 'hist'}", 1, 0.5538000000000001, 0.008280096617793739, 0.619, 0.420621919631958)
# Elapsed time: 0.42s
#
# 42 0.563
# 43 0.563
# 44 0.553
# 45 0.542
# 46 0.548
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 1, 'max_depth': 6, 'tree_method': 'approx'}", 1, 0.5538000000000001, 0.008280096617793739, 0.619, 0.7601757049560547)
# Elapsed time: 0.76s
#
# 42 0.527
# 43 0.545
# 44 0.545
# 45 0.508
# 46 0.56
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 1, 'max_depth': 10, 'tree_method': 'auto'}", 1, 0.537, 0.01787735998406925, 0.5980000000000001, 0.9182228088378906)
# Elapsed time: 0.92s
#
# 42 0.527
# 43 0.545
# 44 0.545
# 45 0.508
# 46 0.56
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 1, 'max_depth': 10, 'tree_method': 'hist'}", 1, 0.537, 0.01787735998406925, 0.5980000000000001, 0.8785387516021729)
# Elapsed time: 0.88s
#
# 42 0.529
# 43 0.545
# 44 0.545
# 45 0.508
# 46 0.56
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 1, 'max_depth': 10, 'tree_method': 'approx'}", 1, 0.5374000000000001, 0.017670314088889326, 0.597, 1.4827863216400146)
# Elapsed time: 1.48s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 3, 'max_depth': 2, 'tree_method': 'auto'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.3056932926177979)
# Elapsed time: 0.31s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 3, 'max_depth': 2, 'tree_method': 'hist'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.30829310417175293)
# Elapsed time: 0.31s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 3, 'max_depth': 2, 'tree_method': 'approx'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.5369823455810547)
# Elapsed time: 0.54s
#
# 42 0.563
# 43 0.563
# 44 0.553
# 45 0.557
# 46 0.548
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 3, 'max_depth': 6, 'tree_method': 'auto'}", 1, 0.5568, 0.0058103356185335376, 0.626, 0.39673557281494143)
# Elapsed time: 0.40s
#
# 42 0.563
# 43 0.563
# 44 0.553
# 45 0.557
# 46 0.548
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 3, 'max_depth': 6, 'tree_method': 'hist'}", 1, 0.5568, 0.0058103356185335376, 0.626, 0.3969999313354492)
# Elapsed time: 0.40s
#
# 42 0.563
# 43 0.563
# 44 0.553
# 45 0.557
# 46 0.548
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 3, 'max_depth': 6, 'tree_method': 'approx'}", 1, 0.5568, 0.0058103356185335376, 0.626, 0.7337514877319335)
# Elapsed time: 0.73s
#
# 42 0.527
# 43 0.545
# 44 0.545
# 45 0.508
# 46 0.549
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 3, 'max_depth': 10, 'tree_method': 'auto'}", 1, 0.5347999999999999, 0.015419468213917119, 0.593, 0.7569225788116455)
# Elapsed time: 0.76s
#
# 42 0.527
# 43 0.545
# 44 0.545
# 45 0.508
# 46 0.549
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 3, 'max_depth': 10, 'tree_method': 'hist'}", 1, 0.5347999999999999, 0.015419468213917119, 0.593, 0.7295107364654541)
# Elapsed time: 0.73s
#
# 42 0.529
# 43 0.545
# 44 0.545
# 45 0.508
# 46 0.549
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 3, 'max_depth': 10, 'tree_method': 'approx'}", 1, 0.5352, 0.015236797563792742, 0.591, 1.3162994384765625)
# Elapsed time: 1.32s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 5, 'max_depth': 2, 'tree_method': 'auto'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.26763463020324707)
# Elapsed time: 0.27s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 5, 'max_depth': 2, 'tree_method': 'hist'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.32922921180725095)
# Elapsed time: 0.33s
#
# 42 0.546
# 43 0.547
# 44 0.558
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 5, 'max_depth': 2, 'tree_method': 'approx'}", 1, 0.5526, 0.005083306010855538, 0.623, 0.5412946701049804)
# Elapsed time: 0.54s
#
# 42 0.581
# 43 0.56
# 44 0.568
# 45 0.542
# 46 0.556
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 5, 'max_depth': 6, 'tree_method': 'auto'}", 1, 0.5614000000000001, 0.012924395537122775, 0.639, 0.41946935653686523)
# Elapsed time: 0.42s
#
# 42 0.581
# 43 0.56
# 44 0.568
# 45 0.542
# 46 0.556
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 5, 'max_depth': 6, 'tree_method': 'hist'}", 1, 0.5614000000000001, 0.012924395537122775, 0.639, 0.4035031795501709)
# Elapsed time: 0.40s
#
# 42 0.581
# 43 0.56
# 44 0.568
# 45 0.542
# 46 0.556
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 5, 'max_depth': 6, 'tree_method': 'approx'}", 1, 0.5614000000000001, 0.012924395537122775, 0.639, 0.7162172794342041)
# Elapsed time: 0.72s
#
# 42 0.535
# 43 0.558
# 44 0.564
# 45 0.536
# 46 0.547
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 5, 'max_depth': 10, 'tree_method': 'auto'}", 1, 0.548, 0.011575836902790205, 0.618, 0.6673984527587891)
# Elapsed time: 0.67s
#
# 42 0.535
# 43 0.558
# 44 0.564
# 45 0.536
# 46 0.547
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 5, 'max_depth': 10, 'tree_method': 'hist'}", 1, 0.548, 0.011575836902790205, 0.618, 0.6512872695922851)
# Elapsed time: 0.65s
#
# 42 0.535
# 43 0.558
# 44 0.564
# 45 0.536
# 46 0.547
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'min_child_weight': 5, 'max_depth': 10, 'tree_method': 'approx'}", 1, 0.548, 0.011575836902790205, 0.62, 1.2373273849487305)
# Elapsed time: 1.24s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 2, 'tree_method': 'auto'}", 1, 0.5604000000000001, 0.011482160075525823, 0.635, 0.6679892539978027)
# Elapsed time: 0.67s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 2, 'tree_method': 'hist'}", 1, 0.5604000000000001, 0.011482160075525823, 0.635, 0.7128967761993408)
# Elapsed time: 0.71s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 2, 'tree_method': 'approx'}", 1, 0.5592, 0.01146123902551549, 0.635, 3.3260021209716797)
# Elapsed time: 3.33s
#
# 42 0.543
# 43 0.554
# 44 0.573
# 45 0.584
# 46 0.579
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 6, 'tree_method': 'auto'}", 1, 0.5666, 0.015576905982896565, 0.643, 2.1549074172973635)
# Elapsed time: 2.15s
#
# 42 0.543
# 43 0.554
# 44 0.573
# 45 0.584
# 46 0.579
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 6, 'tree_method': 'hist'}", 1, 0.5666, 0.015576905982896565, 0.643, 2.1982030391693117)
# Elapsed time: 2.20s
#
# 42 0.545
# 43 0.562
# 44 0.575
# 45 0.584
# 46 0.58
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 6, 'tree_method': 'approx'}", 1, 0.5692, 0.014190137420053373, 0.635, 5.801673412322998)
# Elapsed time: 5.80s
#
# 42 0.559
# 43 0.55
# 44 0.55
# 45 0.537
# 46 0.572
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 10, 'tree_method': 'auto'}", 1, 0.5536000000000001, 0.01156892389118363, 0.627, 6.769452428817749)
# Elapsed time: 6.77s
#
# 42 0.559
# 43 0.55
# 44 0.55
# 45 0.537
# 46 0.572
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 10, 'tree_method': 'hist'}", 1, 0.5536000000000001, 0.01156892389118363, 0.627, 6.798601770401001)
# Elapsed time: 6.80s
#
# 42 0.552
# 43 0.555
# 44 0.55
# 45 0.541
# 46 0.546
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 10, 'tree_method': 'approx'}", 1, 0.5488000000000002, 0.0048744230427815805, 0.625, 16.48123083114624)
# Elapsed time: 16.48s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 2, 'tree_method': 'auto'}", 1, 0.5604000000000001, 0.011482160075525823, 0.635, 0.7193146228790284)
# Elapsed time: 0.72s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 2, 'tree_method': 'hist'}", 1, 0.5604000000000001, 0.011482160075525823, 0.635, 0.6876107692718506)
# Elapsed time: 0.69s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 2, 'tree_method': 'approx'}", 1, 0.5592, 0.01146123902551549, 0.635, 3.3682054042816163)
# Elapsed time: 3.37s
#
# 42 0.578
# 43 0.554
# 44 0.573
# 45 0.584
# 46 0.579
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 6, 'tree_method': 'auto'}", 1, 0.5736000000000001, 0.01040384544291193, 0.655, 2.094928169250488)
# Elapsed time: 2.09s
#
# 42 0.578
# 43 0.554
# 44 0.573
# 45 0.584
# 46 0.579
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 6, 'tree_method': 'hist'}", 1, 0.5736000000000001, 0.01040384544291193, 0.655, 2.166661596298218)
# Elapsed time: 2.17s
#
# 42 0.579
# 43 0.562
# 44 0.575
# 45 0.584
# 46 0.58
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 6, 'tree_method': 'approx'}", 1, 0.576, 0.00756306816047558, 0.6459999999999999, 5.8404935836792)
# Elapsed time: 5.84s
#
# 42 0.559
# 43 0.55
# 44 0.55
# 45 0.537
# 46 0.546
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 10, 'tree_method': 'auto'}", 1, 0.5484, 0.007116178749862885, 0.625, 6.0888965129852295)
# Elapsed time: 6.09s
#
# 42 0.559
# 43 0.55
# 44 0.55
# 45 0.537
# 46 0.546
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 10, 'tree_method': 'hist'}", 1, 0.5484, 0.007116178749862885, 0.625, 6.366127586364746)
# Elapsed time: 6.37s
#
# 42 0.552
# 43 0.555
# 44 0.55
# 45 0.517
# 46 0.546
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 1, 'max_depth': 10, 'tree_method': 'approx'}", 1, 0.5440000000000002, 0.013813037319865619, 0.6060000000000001, 14.033582305908203)
# Elapsed time: 14.03s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 2, 'tree_method': 'auto'}", 1, 0.5604000000000001, 0.011482160075525823, 0.635, 0.7341235160827637)
# Elapsed time: 0.73s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 2, 'tree_method': 'hist'}", 1, 0.5604000000000001, 0.011482160075525823, 0.635, 0.7067575931549073)
# Elapsed time: 0.71s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 2, 'tree_method': 'approx'}", 1, 0.5592, 0.01146123902551549, 0.635, 3.397980070114136)
# Elapsed time: 3.40s
#
# 42 0.578
# 43 0.554
# 44 0.573
# 45 0.584
# 46 0.579
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 6, 'tree_method': 'auto'}", 1, 0.5736000000000001, 0.01040384544291193, 0.655, 2.022071123123169)
# Elapsed time: 2.02s
#
# 42 0.578
# 43 0.554
# 44 0.573
# 45 0.584
# 46 0.579
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 6, 'tree_method': 'hist'}", 1, 0.5736000000000001, 0.01040384544291193, 0.655, 2.0222315788269043)
# Elapsed time: 2.02s
#
# 42 0.579
# 43 0.562
# 44 0.575
# 45 0.584
# 46 0.58
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 6, 'tree_method': 'approx'}", 1, 0.576, 0.00756306816047558, 0.6459999999999999, 5.955533027648926)
# Elapsed time: 5.96s
#
# 42 0.527
# 43 0.55
# 44 0.55
# 45 0.537
# 46 0.573
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 10, 'tree_method': 'auto'}", 1, 0.5474, 0.01544797721386199, 0.607, 5.122851371765137)
# Elapsed time: 5.12s
#
# 42 0.527
# 43 0.55
# 44 0.55
# 45 0.537
# 46 0.573
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 10, 'tree_method': 'hist'}", 1, 0.5474, 0.01544797721386199, 0.607, 4.936711645126342)
# Elapsed time: 4.94s
#
# 42 0.532
# 43 0.555
# 44 0.55
# 45 0.541
# 46 0.566
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 10, 'tree_method': 'approx'}", 1, 0.5488000000000001, 0.011651609330903584, 0.61, 14.125301408767701)
# Elapsed time: 14.13s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 5, 'max_depth': 2, 'tree_method': 'auto'}", 1, 0.5604000000000001, 0.011482160075525823, 0.635, 0.7697028636932373)
# Elapsed time: 0.77s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.563
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 5, 'max_depth': 2, 'tree_method': 'hist'}", 1, 0.5604000000000001, 0.011482160075525823, 0.635, 0.8119672775268555)
# Elapsed time: 0.81s
#
# 42 0.581
# 43 0.547
# 44 0.556
# 45 0.555
# 46 0.557
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 5, 'max_depth': 2, 'tree_method': 'approx'}", 1, 0.5592, 0.01146123902551549, 0.635, 3.750070095062256)
# Elapsed time: 3.75s
#
# 42 0.576
# 43 0.553
# 44 0.561
# 45 0.55
# 46 0.581
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 5, 'max_depth': 6, 'tree_method': 'auto'}", 1, 0.5642, 0.012319090875547554, 0.6440000000000001, 2.088293123245239)
# Elapsed time: 2.09s
#
# 42 0.576
# 43 0.553
# 44 0.561
# 45 0.55
# 46 0.581
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gbtree', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'min_child_weight': 5, 'max_depth': 6, 'tree_method': 'hist'}", 1, 0.5642, 0.012319090875547554, 0.6440000000000001, 2.1037315845489504)
# Elapsed time: 2.10s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 27>()
#      24 ks = np.arange(1, 2, 1)
#      25 train_test_seeds = list(range(42, 47))
# ---> 27 run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds)
#
# Input In [3], in run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds)
#      12 for fs_params in fs_param_combinations:
#      13     for clf_params in clf_param_combinations:
# ---> 14         result = experiment(
#      15             X,
#      16             y,
#      17             fs_cls,
#      18             fs_params,
#      19             clf_cls,
#      20             clf_params,
#      21             k,
#      22             k_param_name,
#      23             requires_estimator,
#      24             train_test_seeds,
#      25         )
#      27         print(result)
#      28         print(f"Elapsed time: {result[-1]:.2f}s\n")
#
# File c:\Users\Tomcio\Documents\AML\AML-project2\code\utils.py:72, in experiment(X, y, fs_cls, fs_kwargs, clf_cls, clf_kwargs, n_features, k_param_name, requires_estimator, train_test_seeds)
#      58 def experiment(
#      59     X,
#      60     y,
#    (...)
#      69 ):
#      70     # Run experiment
#      71     start = time.time()
# ---> 72     accs, accs_top_20pc = _experiment_internal(
#      73         X,
#      74         y,
#      75         fs_cls,
#      76         fs_kwargs,
#      77         clf_cls,
#      78         clf_kwargs,
#      79         n_features,
#      80         k_param_name,
#      81         requires_estimator,
#      82         train_test_seeds,
#      83     )
#      84     elapsed = time.time() - start
#      85     elapsed = elapsed / len(train_test_seeds)
#
# File c:\Users\Tomcio\Documents\AML\AML-project2\code\utils.py:142, in _experiment_internal(X, y, fs_cls, fs_kwargs, clf_cls, clf_kwargs, n_features, k_param_name, requires_estimator, train_test_seeds)
#     133 X_train, X_test, y_train, y_test = train_test_split(
#     134     X,
#     135     y,
#    (...)
#     138     random_state=seed,
#     139 )
#     141 # Feature selection
# --> 142 X_train = feature_selector.fit_transform(X_train, y_train)
#     143 X_test = feature_selector.transform(X_test)
#     145 # Training
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:1101, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
# -> 1101     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_from_model.py:388, in SelectFromModel.fit(self, X, y, **fit_params)
#     385     else:
#     386         # TODO(SLEP6): remove when metadata routing cannot be disabled.
#     387         self.estimator_ = clone(self.estimator)
# --> 388         self.estimator_.fit(X, y, **fit_params)
#     390 if hasattr(self.estimator_, "feature_names_in_"):
#     391     self.feature_names_in_ = self.estimator_.feature_names_in_
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1519, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1491 (
#    1492     model,
#    1493     metric,
#    (...)
#    1498     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1499 )
#    1500 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1501     missing=self.missing,
#    1502     X=X,
#    (...)
#    1516     feature_types=self.feature_types,
#    1517 )
# -> 1519 self._Booster = train(
#    1520     params,
#    1521     train_dmatrix,
#    1522     self.get_num_boosting_rounds(),
#    1523     evals=evals,
#    1524     early_stopping_rounds=early_stopping_rounds,
#    1525     evals_result=evals_result,
#    1526     obj=obj,
#    1527     custom_metric=metric,
#    1528     verbose_eval=verbose,
#    1529     xgb_model=model,
#    1530     callbacks=callbacks,
#    1531 )
#    1533 if not callable(self.objective):
#    1534     self.objective = params["objective"]
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
results = []

filename = "tomkowe_linear"

feature_selectors = [
    (SelectFromModel, {"threshold": [-np.inf]}, "max_features", True)
]

classifiers = [
    (
        XGBClassifier,
        {
            "booster": ["gblinear"],
            "device": ["gpu"],
            "learning_rate": [0.001, 0.01, 0.1, 0.2, 0.3, 0.5],
            "n_estimators": [10, 100, 200, 300],
            "updater": ["coord_descent", "shotgun"]
        }
    )
]

ks = np.arange(1, 10, 1)
train_test_seeds = list(range(42, 47))

run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds)
# Out:
# 42 0.501
# 43 0.501
# 44 0.502
# 45 0.501
# 46 0.501
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'updater': 'coord_descent'}", 1, 0.5012, 0.00040000000000000034, 0.505, 1.261199426651001)
# Elapsed time: 1.26s
#
# 42 0.501
# 43 0.501
# 44 0.502
# 45 0.501
# 46 0.501
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'updater': 'shotgun'}", 1, 0.5012, 0.00040000000000000034, 0.505, 0.17819948196411134)
# Elapsed time: 0.18s
#
# 42 0.505
# 43 0.509
# 44 0.496
# 45 0.495
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'updater': 'coord_descent'}", 1, 0.5016, 0.005351635264103866, 0.506, 11.837090826034546)
# Elapsed time: 11.84s
#
# 42 0.505
# 43 0.509
# 44 0.496
# 45 0.495
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'updater': 'shotgun'}", 1, 0.5016, 0.005351635264103866, 0.506, 0.7037909030914307)
# Elapsed time: 0.70s
#
# 42 0.506
# 43 0.503
# 44 0.492
# 45 0.5
# 46 0.51
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 200, 'updater': 'coord_descent'}", 1, 0.5022, 0.006079473661428271, 0.499, 23.790149641036987)
# Elapsed time: 23.79s
#
# 42 0.506
# 43 0.503
# 44 0.492
# 45 0.5
# 46 0.51
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 200, 'updater': 'shotgun'}", 1, 0.5022, 0.006079473661428271, 0.499, 1.3141272068023682)
# Elapsed time: 1.31s
#
# 42 0.499
# 43 0.5
# 44 0.487
# 45 0.498
# 46 0.506
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 300, 'updater': 'coord_descent'}", 1, 0.49800000000000005, 0.006164414002968982, 0.499, 35.21432824134827)
# Elapsed time: 35.21s
#
# 42 0.499
# 43 0.5
# 44 0.487
# 45 0.498
# 46 0.506
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 300, 'updater': 'shotgun'}", 1, 0.49800000000000005, 0.006164414002968982, 0.499, 1.9020719528198242)
# Elapsed time: 1.90s
#
# 42 0.505
# 43 0.509
# 44 0.496
# 45 0.495
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.01, 'n_estimators': 10, 'updater': 'coord_descent'}", 1, 0.5038, 0.007359347797189646, 0.5, 1.327748918533325)
# Elapsed time: 1.33s
#
# 42 0.505
# 43 0.509
# 44 0.496
# 45 0.495
# 46 0.514
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.01, 'n_estimators': 10, 'updater': 'shotgun'}", 1, 0.5038, 0.007359347797189646, 0.5, 0.18318643569946289)
# Elapsed time: 0.18s
#
# 42 0.501
# 43 0.497
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.01, 'n_estimators': 100, 'updater': 'coord_descent'}", 1, 0.499, 0.004049691346263321, 0.499, 12.190307521820069)
# Elapsed time: 12.19s
#
# 42 0.501
# 43 0.497
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.01, 'n_estimators': 100, 'updater': 'shotgun'}", 1, 0.499, 0.004049691346263321, 0.499, 0.6267481327056885)
# Elapsed time: 0.63s
#
# 42 0.48
# 43 0.501
# 44 0.492
# 45 0.502
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.01, 'n_estimators': 200, 'updater': 'coord_descent'}", 1, 0.49539999999999995, 0.008569714114251427, 0.501, 24.075558853149413)
# Elapsed time: 24.08s
#
# 42 0.48
# 43 0.501
# 44 0.492
# 45 0.502
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.01, 'n_estimators': 200, 'updater': 'shotgun'}", 1, 0.49539999999999995, 0.008569714114251427, 0.501, 1.17073712348938)
# Elapsed time: 1.17s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.503
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.01, 'n_estimators': 300, 'updater': 'coord_descent'}", 1, 0.4958, 0.008423775875461082, 0.501, 36.090910005569455)
# Elapsed time: 36.09s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.503
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.01, 'n_estimators': 300, 'updater': 'shotgun'}", 1, 0.4958, 0.008423775875461082, 0.501, 1.8461897850036622)
# Elapsed time: 1.85s
#
# 42 0.5
# 43 0.498
# 44 0.492
# 45 0.501
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.1, 'n_estimators': 10, 'updater': 'coord_descent'}", 1, 0.4988, 0.003762977544445359, 0.499, 1.3370333671569825)
# Elapsed time: 1.34s
#
# 42 0.5
# 43 0.498
# 44 0.492
# 45 0.501
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.1, 'n_estimators': 10, 'updater': 'shotgun'}", 1, 0.4988, 0.003762977544445359, 0.499, 0.16357297897338868)
# Elapsed time: 0.16s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.1, 'n_estimators': 100, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 12.144763946533203)
# Elapsed time: 12.14s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.1, 'n_estimators': 100, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 0.7475761413574219)
# Elapsed time: 0.75s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.1, 'n_estimators': 200, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 24.048275661468505)
# Elapsed time: 24.05s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.1, 'n_estimators': 200, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 1.2267941951751709)
# Elapsed time: 1.23s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.1, 'n_estimators': 300, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 35.951596927642825)
# Elapsed time: 35.95s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.1, 'n_estimators': 300, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 1.9516097068786622)
# Elapsed time: 1.95s
#
# 42 0.48
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.2, 'n_estimators': 10, 'updater': 'coord_descent'}", 1, 0.4952, 0.00844748483277716, 0.501, 1.350817584991455)
# Elapsed time: 1.35s
#
# 42 0.48
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.2, 'n_estimators': 10, 'updater': 'shotgun'}", 1, 0.4952, 0.00844748483277716, 0.501, 0.1704390048980713)
# Elapsed time: 0.17s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.2, 'n_estimators': 100, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 12.092609882354736)
# Elapsed time: 12.09s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.2, 'n_estimators': 100, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 0.6507594585418701)
# Elapsed time: 0.65s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.2, 'n_estimators': 200, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 23.97537236213684)
# Elapsed time: 23.98s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.2, 'n_estimators': 200, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 1.2363128185272216)
# Elapsed time: 1.24s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.2, 'n_estimators': 300, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 35.91733274459839)
# Elapsed time: 35.92s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.2, 'n_estimators': 300, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 1.693587636947632)
# Elapsed time: 1.69s
#
# 42 0.481
# 43 0.5
# 44 0.491
# 45 0.503
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.3, 'n_estimators': 10, 'updater': 'coord_descent'}", 1, 0.49560000000000004, 0.008522910301065015, 0.501, 1.358986759185791)
# Elapsed time: 1.36s
#
# 42 0.481
# 43 0.5
# 44 0.491
# 45 0.503
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.3, 'n_estimators': 10, 'updater': 'shotgun'}", 1, 0.49560000000000004, 0.008522910301065015, 0.501, 0.17119989395141602)
# Elapsed time: 0.17s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.3, 'n_estimators': 100, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 11.985871839523316)
# Elapsed time: 11.99s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.3, 'n_estimators': 100, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 0.670362138748169)
# Elapsed time: 0.67s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.3, 'n_estimators': 200, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 24.05856590270996)
# Elapsed time: 24.06s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.3, 'n_estimators': 200, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 1.2784646034240723)
# Elapsed time: 1.28s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.3, 'n_estimators': 300, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 35.82025966644287)
# Elapsed time: 35.82s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.3, 'n_estimators': 300, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 1.9206977367401123)
# Elapsed time: 1.92s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.5, 'n_estimators': 10, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 1.3516283988952638)
# Elapsed time: 1.35s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.5, 'n_estimators': 10, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 0.17105484008789062)
# Elapsed time: 0.17s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.5, 'n_estimators': 100, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 12.049807262420654)
# Elapsed time: 12.05s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.5, 'n_estimators': 100, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 0.6347002506256103)
# Elapsed time: 0.63s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.5, 'n_estimators': 200, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 24.000537633895874)
# Elapsed time: 24.00s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.5, 'n_estimators': 200, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 1.3343606472015381)
# Elapsed time: 1.33s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.5, 'n_estimators': 300, 'updater': 'coord_descent'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 35.882856893539426)
# Elapsed time: 35.88s
#
# 42 0.481
# 43 0.5
# 44 0.492
# 45 0.502
# 46 0.503
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.5, 'n_estimators': 300, 'updater': 'shotgun'}", 1, 0.49559999999999993, 0.008260750571225361, 0.501, 1.7542605876922608)
# Elapsed time: 1.75s
#
# 42 0.499
# 43 0.501
# 44 0.502
# 45 0.499
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'updater': 'coord_descent'}", 2, 0.5006, 0.001356465996625055, 0.497, 1.3407063961029053)
# Elapsed time: 1.34s
#
# 42 0.499
# 43 0.501
# 44 0.502
# 45 0.499
# 46 0.502
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 10, 'updater': 'shotgun'}", 2, 0.5006, 0.001356465996625055, 0.497, 0.1669997215270996)
# Elapsed time: 0.17s
#
# 42 0.496
# 43 0.502
# 44 0.506
# 45 0.479
# 46 0.492
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'updater': 'coord_descent'}", 2, 0.495, 0.00933809402394301, 0.501, 12.076423501968383)
# Elapsed time: 12.08s
#
# 42 0.496
# 43 0.502
# 44 0.506
# 45 0.479
# 46 0.492
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 100, 'updater': 'shotgun'}", 2, 0.495, 0.00933809402394301, 0.501, 0.6243573665618897)
# Elapsed time: 0.62s
#
# 42 0.489
# 43 0.508
# 44 0.51
# 45 0.478
# 46 0.504
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 200, 'updater': 'coord_descent'}", 2, 0.49779999999999996, 0.01233531515608743, 0.501, 24.05310926437378)
# Elapsed time: 24.05s
#
# 42 0.489
# 43 0.508
# 44 0.51
# 45 0.478
# 46 0.504
# ('SelectFromModel', "{'threshold': -Infinity}", 'XGBClassifier', "{'booster': 'gblinear', 'device': 'gpu', 'learning_rate': 0.001, 'n_estimators': 200, 'updater': 'shotgun'}", 2, 0.49779999999999996, 0.01233531515608743, 0.501, 1.2256484031677246)
# Elapsed time: 1.23s
#
# 42 0.486
# 43 0.505
# 44 0.506
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 25>()
#      22 ks = np.arange(1, 10, 1)
#      23 train_test_seeds = list(range(42, 47))
# ---> 25 run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds)
#
# Input In [3], in run_experiment(feature_selectors, classifiers, ks, results, train_test_seeds)
#      12 for fs_params in fs_param_combinations:
#      13     for clf_params in clf_param_combinations:
# ---> 14         result = experiment(
#      15             X,
#      16             y,
#      17             fs_cls,
#      18             fs_params,
#      19             clf_cls,
#      20             clf_params,
#      21             k,
#      22             k_param_name,
#      23             requires_estimator,
#      24             train_test_seeds,
#      25         )
#      27         print(result)
#      28         print(f"Elapsed time: {result[-1]:.2f}s\n")
#
# File c:\Users\Tomcio\Documents\AML\AML-project2\code\utils.py:72, in experiment(X, y, fs_cls, fs_kwargs, clf_cls, clf_kwargs, n_features, k_param_name, requires_estimator, train_test_seeds)
#      58 def experiment(
#      59     X,
#      60     y,
#    (...)
#      69 ):
#      70     # Run experiment
#      71     start = time.time()
# ---> 72     accs, accs_top_20pc = _experiment_internal(
#      73         X,
#      74         y,
#      75         fs_cls,
#      76         fs_kwargs,
#      77         clf_cls,
#      78         clf_kwargs,
#      79         n_features,
#      80         k_param_name,
#      81         requires_estimator,
#      82         train_test_seeds,
#      83     )
#      84     elapsed = time.time() - start
#      85     elapsed = elapsed / len(train_test_seeds)
#
# File c:\Users\Tomcio\Documents\AML\AML-project2\code\utils.py:142, in _experiment_internal(X, y, fs_cls, fs_kwargs, clf_cls, clf_kwargs, n_features, k_param_name, requires_estimator, train_test_seeds)
#     133 X_train, X_test, y_train, y_test = train_test_split(
#     134     X,
#     135     y,
#    (...)
#     138     random_state=seed,
#     139 )
#     141 # Feature selection
# --> 142 X_train = feature_selector.fit_transform(X_train, y_train)
#     143 X_test = feature_selector.transform(X_test)
#     145 # Training
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:1101, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
# -> 1101     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_from_model.py:388, in SelectFromModel.fit(self, X, y, **fit_params)
#     385     else:
#     386         # TODO(SLEP6): remove when metadata routing cannot be disabled.
#     387         self.estimator_ = clone(self.estimator)
# --> 388         self.estimator_.fit(X, y, **fit_params)
#     390 if hasattr(self.estimator_, "feature_names_in_"):
#     391     self.feature_names_in_ = self.estimator_.feature_names_in_
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\sklearn.py:1519, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1491 (
#    1492     model,
#    1493     metric,
#    (...)
#    1498     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1499 )
#    1500 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1501     missing=self.missing,
#    1502     X=X,
#    (...)
#    1516     feature_types=self.feature_types,
#    1517 )
# -> 1519 self._Booster = train(
#    1520     params,
#    1521     train_dmatrix,
#    1522     self.get_num_boosting_rounds(),
#    1523     evals=evals,
#    1524     early_stopping_rounds=early_stopping_rounds,
#    1525     evals_result=evals_result,
#    1526     obj=obj,
#    1527     custom_metric=metric,
#    1528     verbose_eval=verbose,
#    1529     xgb_model=model,
#    1530     callbacks=callbacks,
#    1531 )
#    1533 if not callable(self.objective):
#    1534     self.objective = params["objective"]
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File c:\Users\Tomcio\AppData\Local\Programs\Python\Python39\lib\site-packages\xgboost\core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
